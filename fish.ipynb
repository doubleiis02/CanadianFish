# %%
import numpy as np

# %%
from random import shuffle

# %%
low_d_set = ['2 of diamonds', '3 of diamonds', '4 of diamonds', '5 of diamonds', '6 of diamonds', '7 of diamonds']
high_d_set = ['9 of diamonds', '10 of diamonds', 'jack of diamonds', 'queen of diamonds', 'king of diamonds', 'ace of diamonds']
low_c_set = ['2 of clubs', '3 of clubs', '4 of clubs', '5 of clubs', '6 of clubs', '7 of clubs']
high_c_set = ['9 of clubs', '10 of clubs', 'jack of clubs', 'queen of clubs', 'king of clubs', 'ace of clubs']
low_s_set = ['2 of spades', '3 of spades', '4 of spades', '5 of spades', '6 of spades', '7 of spades']
high_s_set = ['9 of spades', '10 of spades', 'jack of spades', 'queen of spades', 'king of spades', 'ace of spades']
low_h_set = ['2 of hearts', '3 of hearts', '4 of hearts', '5 of hearts', '6 of hearts', '7 of hearts']
high_h_set = ['9 of hearts', '10 of hearts', 'jack of hearts', 'queen of hearts', 'king of hearts', 'ace of hearts']
middle_set = ['black joker', 'red joker', '8 of diamonds', '8 of clubs', '8 of spades', '8 of hearts']

# %%
whole_deck = low_d_set + low_c_set + low_s_set + low_h_set + middle_set + high_d_set + high_c_set + high_s_set + high_h_set

# %%
order = []
for c in whole_deck:
    order.append(c)
print(order)
# Out:
# ['2 of diamonds', '3 of diamonds', '4 of diamonds', '5 of diamonds', '6 of diamonds', '7 of diamonds', '2 of clubs', '3 of clubs', '4 of clubs', '5 of clubs', '6 of clubs', '7 of clubs', '2 of spades', '3 of spades', '4 of spades', '5 of spades', '6 of spades', '7 of spades', '2 of hearts', '3 of hearts', '4 of hearts', '5 of hearts', '6 of hearts', '7 of hearts', 'black joker', 'red joker', '8 of diamonds', '8 of clubs', '8 of spades', '8 of hearts', '9 of diamonds', '10 of diamonds', 'jack of diamonds', 'queen of diamonds', 'king of diamonds', 'ace of diamonds', '9 of clubs', '10 of clubs', 'jack of clubs', 'queen of clubs', 'king of clubs', 'ace of clubs', '9 of spades', '10 of spades', 'jack of spades', 'queen of spades', 'king of spades', 'ace of spades', '9 of hearts', '10 of hearts', 'jack of hearts', 'queen of hearts', 'king of hearts', 'ace of hearts']

# %%
rules = "There are no rules available as of now. Sorry!"

# %%
shuffle(whole_deck)

# %%
low_h_ingame = True
low_c_ingame = True
low_s_ingame = True
low_d_ingame = True
high_h_ingame = True
high_c_ingame = True
high_s_ingame = True
high_d_ingame = True
middle_ingame = True

player_hyp_Carlview = {}
for i in whole_deck:
    player_hyp_Carlview[i] = 1/14
Carl_hyp_Bobview = {}
for i in whole_deck:
    Carl_hyp_Bobview[i] = 1/13

Bob_hyp_Carlview = Carl_hyp_Bobview.copy()
Amy_hyp_Carlview = player_hyp_Carlview.copy()

player_hyp_Bobview = player_hyp_Carlview.copy()
Amy_hyp_Bobview = player_hyp_Carlview.copy()

player_hyp_Amyview = player_hyp_Carlview.copy()
Carl_hyp_Amyview = Carl_hyp_Bobview.copy()
Bob_hyp_Amyview = Carl_hyp_Bobview.copy()

# %%
class Player:
    def __init__(self, name, cards):
        """
        name = string, player's name
        cards = list of cards they have
        """
        
        self.name = name
        self.cards = cards

# %%
def setup_players(name):
    player = Player(name, whole_deck[:14])
    Carl = Player("Carl", whole_deck[14:27])
    Bob = Player("Bob", whole_deck[27:40])
    Amy = Player("Amy", whole_deck[40:54])
    return player, Carl, Bob, Amy

# %%
def sort_cards(cards):
    cards.sort(key=lambda x: order.index(x))
    return cards

# %%
def check_cards(cards):
    print("Your cards are:\n")
    for c in cards:
        print(c)
    print('\n')

# %%
def which_set(card):
    if card in low_d_set:
        return low_d_set
    elif card in high_d_set:
        return high_d_set
    elif card in low_c_set:
        return high_c_set
    elif card in low_s_set:
        return low_s_set
    elif card in high_s_set:
        return high_s_set
    elif card in low_h_set:
        return low_h_set
    elif card in high_h_set:
        return high_h_set
    else:
        return middle_set

def ask(card, who_to_ask, person_playing, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    if who_to_ask == player or who_to_ask == Carl or who_to_ask.cards == []:
        print("You cannot ask this person.")
        who_to_ask = input("Who will you ask, Bob or Amy?")
        if who_to_ask == player or who_to_ask == Carl or who_to_ask.cards == []:
            print("You're stupid. You lose your turn.")
            return np.random.randint(2,4), player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if card in person_playing.cards:
        print("You have that card and therefore cannot ask someone else for it.")
        
        player_hyp_Carlview[card] = 1
        player_hyp_Bobview[card] = 1
        player_hyp_Amyview[card] = 1
        
        card = input("Which card will you ask for?")
        if card in person_playing.cards:
            player_hyp_Carlview[card] = 1
            player_hyp_Bobview[card] = 1
            player_hyp_Amyview[card] = 1
            print("You're stupid. You lose your turn.")
            return np.random.randint(2,4), player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    set_ = which_set(card)
    
    i = 0
    for c in person_playing.cards:
        if c in set_:
            i = 1
            break
            
    if i == 1:
        if card in who_to_ask.cards:
            person_playing.cards.append(card)
            who_to_ask.cards.pop(who_to_ask.cards.index(card))
            print("You took the ", card, " from ", who_to_ask.name)
            
            player_hyp_Carlview[card] = 1
            player_hyp_Bobview[card] = 1
            player_hyp_Amyview[card] = 1
            
            
            num = 0
            for pos in player_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and player_hyp_Carlview[pos] is not 0 and player_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in player_hyp_Carlview:
                    num = (player_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and player_hyp_Carlview[pos] is not 0 and player_hyp_Carlview[pos] is not 1:
                        player_hyp_Carlview[pos] = num
                            
            num = 0
            for pos in player_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and player_hyp_Bobview[pos] is not 0 and player_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                for pos in player_hyp_Bobview:
                    num = (player_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and player_hyp_Bobview[pos] is not 0 and player_hyp_Bobview[pos] is not 1:
                        player_hyp_Bobview[pos] = num
           
            num = 0
            for pos in player_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and player_hyp_Amyview[pos] is not 0 and player_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                for pos in player_hyp_Amyview:
                    num = (player_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and player_hyp_Amyview[pos] is not 0 and player_hyp_Amyview[pos] is not 1:
                        player_hyp_Amyview[pos] = num
            
            
            
            if who_to_ask == Bob:
                Bob_hyp_Carlview[card] = 0
                Bob_hyp_Amyview[card] = 0
            if who_to_ask == Amy:
                Amy_hyp_Carlview[card] = 0
                Amy_hyp_Bobview[card] = 0
            
            return turns[person_playing], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
        else:
            print(who_to_ask.name, " does not have that card." )
            
            player_hyp_Carlview[card] = 0
            player_hyp_Bobview[card] = 0
            player_hyp_Amyview[card] = 0
            
            num = 0
            for pos in player_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and player_hyp_Carlview[pos] is not 0 and player_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in player_hyp_Carlview:
                    num = (player_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and player_hyp_Carlview[pos] is not 0 and player_hyp_Carlview[pos] is not 1:
                        player_hyp_Carlview[pos] = num
                            
            num = 0
            for pos in player_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and player_hyp_Bobview[pos] is not 0 and player_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                for pos in player_hyp_Bobview:
                    num = (player_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and player_hyp_Bobview[pos] is not 0 and player_hyp_Bobview[pos] is not 1:
                        player_hyp_Bobview[pos] = num
           
            num = 0
            for pos in player_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and player_hyp_Amyview[pos] is not 0 and player_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                for pos in player_hyp_Amyview:
                    num = (player_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and player_hyp_Amyview[pos] is not 0 and player_hyp_Amyview[pos] is not 1:
                        player_hyp_Amyview[pos] = num
            
            if who_to_ask == Bob:
                Bob_hyp_Carlview[card] = 0
                Bob_hyp_Amyview[card] = 0
            if who_to_ask == Amy:
                Amy_hyp_Carlview[card] = 0
                Amy_hyp_Bobview[card] = 0
            
            return turns[who_to_ask], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    else:
        print("You have chosen to ask for a card in a set you do not have. Your turn is over.")
        
        for pos in player_hyp_Carlview:
            if pos in set_:
                player_hyp_Carlview[pos] = 0
        for pos in player_hyp_Bobview:
            if pos in set_:
                player_hyp_Bobview[pos] = 0
        for pos in player_hyp_Amyview:
            if pos in set_:
                player_hyp_Amyview[pos] = 0
                
        
        return turns[who_to_ask], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
def initialize_hyps(player, Carl, Bob, Amy):
    for v in player_hyp_Carlview:
        if v in Carl.cards:
            player_hyp_Carlview[v] = 0
    for v in Bob_hyp_Carlview:
        if v in Carl.cards:
            Bob_hyp_Carlview[v] = 0
    for v in Amy_hyp_Carlview:
        if v in Carl.cards:
            Amy_hyp_Carlview[v] = 0
            
    for v in player_hyp_Bobview:
        if v in Bob.cards:
            player_hyp_Bobview[v] = 0
    for v in Carl_hyp_Bobview:
        if v in Bob.cards:
            Carl_hyp_Bobview[v] = 0
    for v in Amy_hyp_Bobview:
        if v in Bob.cards:
            Amy_hyp_Bobview[v] = 0
            
            
    for v in player_hyp_Amyview:
        if v in Amy.cards:
            player_hyp_Amyview[v] = 0
    for v in Carl_hyp_Amyview:
        if v in Amy.cards:
            Carl_hyp_Amyview[v] = 0
    for v in Bob_hyp_Amyview:
        if v in Amy.cards:
            Bob_hyp_Amyview[v] = 0

# %%
def deleteset(set_, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    l = []
    for val in player_hyp_Carlview:
        if val in set_:
            l.append(val)
    for thing in l:
        del player_hyp_Carlview[thing]        
            
    l = []
    for val in player_hyp_Bobview:
        if val in set_:
            l.append(val)
    for thing in l:
        del player_hyp_Bobview[thing]   
            
    l = []
    for val in player_hyp_Amyview:
        if val in set_:
            l.append(val)
    for thing in l:
        del player_hyp_Amyview[thing]   
            
    l = []
    for val in Carl_hyp_Bobview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Carl_hyp_Bobview[thing]   
            
    l = []
    for val in Amy_hyp_Bobview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Amy_hyp_Bobview[thing]   
            
    l = []
    for val in Bob_hyp_Carlview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Bob_hyp_Carlview[thing]   
            
    l = []
    for val in Amy_hyp_Carlview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Amy_hyp_Carlview[thing]   
            
    l = []
    for val in Carl_hyp_Amyview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Carl_hyp_Amyview[thing]   
            
    l = []
    for val in Bob_hyp_Amyview:
        if val in set_:
            l.append(val)
    for thing in l:
        del Bob_hyp_Amyview[thing]
    return player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
hyplist = [player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview]

# %%
def call(teamscore, oppscore, person_playing, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview, low_h_ingame, low_c_ingame, low_s_ingame, low_d_ingame, high_h_ingame, high_c_ingame, high_s_ingame, high_d_ingame, middle_ingame):
    print("Which set would you like to call?")
    if low_h_ingame == True:
          print("Type 1 for low hearts")
    if low_c_ingame == True:
          print("Type 2 for low clubs")
    if low_s_ingame == True:
          print("Type 3 for low spades")
    if low_d_ingame == True:
          print("Type 4 for low diamonds")
    if high_h_ingame == True:
          print("Type 5 for high hearts")
    if high_c_ingame == True:
          print("Type 6 for high clubs")
    if high_s_ingame == True:
          print("Type 7 for high spades")
    if high_d_ingame == True:
          print("Type 8 for high diamonds")
    if middle_ingame == True:
          print("Type 9 for 8s and Jokers")
    inp = input("")
    if inp != '1' and inp != '2' and inp != '3' and inp != '4' and inp != '5' and inp != '6' and inp != '7' and inp != '8' and inp != '9':
        inp = input("Try again. Type a number between 1 to 9.")
    
    if inp == '1':
        set_ = low_h_set
        low_h_ingame = False
        i = 0
        for card in low_h_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in low_h_set:
                         member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in low_h_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(low_h_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '2':
        set_ = low_c_set
        low_c_ingame = False
        i = 0
        for card in low_c_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in low_c_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in low_c_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(low_c_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '3':
        set_ = low_s_set
        low_s_ingame = False
        i = 0
        for card in low_s_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in low_s_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in low_s_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(low_s_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '4':
        set_ = low_d_set
        low_d_ingame = False
        i = 0
        for card in low_d_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in low_d_set:
                         member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in low_d_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(low_d_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '5':
        set_ = high_h_set
        high_h_ingame = False
        i = 0
        for card in high_h_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in high_h_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in high_h_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(high_h_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '6':
        set_ = high_c_set
        high_c_ingame = False
        i = 0
        for card in high_c_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in high_c_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in high_c_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(high_c_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '7':
        set_ = high_s_set
        high_s_ingame = False
        i = 0
        for card in high_s_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in high_s_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in high_s_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(high_s_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '8':
        set_ = high_d_set
        high_d_ingame = False
        i = 0
        for card in high_d_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in high_d_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in high_d_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(high_d_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    if inp == '9':
        set_ = middle_set
        middle_ingame = False
        i = 0
        for card in middle_set:
            if card not in person_playing.cards + Carl.cards:
                i = 1
        if i == 1:
            #pop the cards out of deck from everyone
            members = [person_playing, Carl, Bob, Amy]
            for member in members:
                for card in member.cards:
                    if card in middle_set:
                        member.cards.pop(member.cards.index(card))
            oppscore += 1
            print("Oh no :( Your team did not have the whole set. Opposing team gets the set. Your score: ", teamscore, " Opposing team score: ", oppscore)
        else:
            members = [person_playing, Carl]
            for member in members:
                for card in member.cards:
                    if card in middle_set:
                        member.cards.pop(member.cards.index(card))
            teamscore += 1
            print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
    
    
        for s in hyplist:
            l=[]
            for c in s:
                if c in set_:
                    l.append(c)
            for thing in l:
                s.pop(thing)
        player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(middle_set, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
        return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
def ask_bot(bot, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    card, who_to_ask, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = choose_card(bot, player, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
    set_ = which_set(card)
    
            
 
    if card in who_to_ask.cards:
        bot.cards.append(card)
        who_to_ask.cards.pop(who_to_ask.cards.index(card))
        print(bot.name, " took the ", card, " from ", who_to_ask.name)

        
        if bot == Carl:
            Carl_hyp_Bobview[card] = 1
            Carl_hyp_Amyview[card] = 1
        elif bot == Bob:
            Bob_hyp_Carlview[card] = 1
            Bob_hyp_Amyview[card] = 1
        else:
            Amy_hyp_Bobview[card] = 1
            Amy_hyp_Carlview[card] = 1

            
        # possibility based on set they asked for    
        
        if bot == Carl:
            num = 0
            for pos in Carl_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and Carl_hyp_Bobview[pos] is not 0 and Carl_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Carl_hyp_Bobview:
                    num = (Carl_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and Carl_hyp_Bobview[pos] is not 0 and Carl_hyp_Bobview[pos] is not 1:
                        Carl_hyp_Bobview[pos] = num
            num = 0
            for pos in Carl_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and Carl_hyp_Amyview[pos] is not 0 and Carl_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Carl_hyp_Amyview:
                    num = (Carl_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and Carl_hyp_Amyview[pos] is not 0 and Carl_hyp_Amyview[pos] is not 1:
                        Carl_hyp_Amyview[pos] = num
        elif bot == Bob:
            num = 0
            for pos in Bob_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and Bob_hyp_Carlview[pos] is not 0 and Bob_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Bob_hyp_Carlview:
                    num = (Bob_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and Bob_hyp_Carlview[pos] is not 0 and Bob_hyp_Carlview[pos] is not 1:
                        Bob_hyp_Carlview[pos] = num
            num = 0
            for pos in Bob_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and Bob_hyp_Amyview[pos] is not 0 and Bob_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Bob_hyp_Amyview:
                    num = (Bob_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and Bob_hyp_Amyview[pos] is not 0 and Bob_hyp_Amyview[pos] is not 1:
                        Bob_hyp_Amyview[pos] = num
        else:
            num = 0
            for pos in Amy_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and Amy_hyp_Bobview[pos] is not 0 and Amy_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Amy_hyp_Bobview:
                    num = (Amy_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and Amy_hyp_Bobview[pos] is not 0 and Amy_hyp_Bobview[pos] is not 1:
                        Amy_hyp_Bobview[pos] = num
            num = 0
            for pos in Amy_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and Amy_hyp_Carlview[pos] is not 0 and Amy_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Amy_hyp_Carlview:
                    num = (Amy_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and Amy_hyp_Carlview[pos] is not 0 and Amy_hyp_Carlview[pos] is not 1:
                        Amy_hyp_Carlview[pos] = num
       

        #taking away card
        if who_to_ask == Bob:
            Bob_hyp_Carlview[card] = 0
            Bob_hyp_Amyview[card] = 0
        elif who_to_ask == Amy:
            Amy_hyp_Carlview[card] = 0
            Amy_hyp_Bobview[card] = 0
        elif who_to_ask == Carl:
            Carl_hyp_Amyview[card] = 0
            Carl_hyp_Bobview[card] = 0
        elif who_to_ask == player:
            player_hyp_Carlview[card] = 0
            player_hyp_Bobview[card] = 0
            player_hyp_Amyview[card] = 0

        return turns[bot], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    
    else:
        print(bot.name, " asked ", who_to_ask.name, " for the ", card, ", but ", who_to_ask.name, " did not have it.")

        
        #bot doesnt have card
        if bot == Carl:
            Carl_hyp_Bobview[card] = 0
            Carl_hyp_Amyview[card] = 0
        elif bot == Bob:
            Bob_hyp_Carlview[card] = 0
            Bob_hyp_Amyview[card] = 0
        else:
            Amy_hyp_Bobview[card] = 0
            Amy_hyp_Carlview[card] = 0


        if bot == Carl:
            num = 0
            for pos in Carl_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and Carl_hyp_Bobview[pos] is not 0 and Carl_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Carl_hyp_Bobview:
                    num = (Carl_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and Carl_hyp_Bobview[pos] is not 0 and Carl_hyp_Bobview[pos] is not 1:
                        Carl_hyp_Bobview[pos] = num
            num = 0
            for pos in Carl_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and Carl_hyp_Amyview[pos] is not 0 and Carl_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Carl_hyp_Amyview:
                    num = (Carl_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and Carl_hyp_Amyview[pos] is not 0 and Carl_hyp_Amyview[pos] is not 1:
                        Carl_hyp_Amyview[pos] = num
        elif bot == Bob:
            num = 0
            for pos in Bob_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and Bob_hyp_Carlview[pos] is not 0 and Bob_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Bob_hyp_Carlview:
                    num = (Bob_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and Bob_hyp_Carlview[pos] is not 0 and Bob_hyp_Carlview[pos] is not 1:
                        Bob_hyp_Carlview[pos] = num
            num = 0
            for pos in Bob_hyp_Amyview:
                if pos not in Amy.cards and pos in set_ and pos is not card and Bob_hyp_Amyview[pos] is not 0 and Bob_hyp_Amyview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Bob_hyp_Amyview:
                    num = (Bob_hyp_Amyview[pos] + num) / 2
                    if pos not in Amy.cards and pos in set_ and pos is not card and Bob_hyp_Amyview[pos] is not 0 and Bob_hyp_Amyview[pos] is not 1:
                        Bob_hyp_Amyview[pos] = num
        else:
            num = 0
            for pos in Amy_hyp_Bobview:
                if pos not in Bob.cards and pos in set_ and pos is not card and Amy_hyp_Bobview[pos] is not 0 and Amy_hyp_Bobview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Amy_hyp_Bobview:
                    num = (Amy_hyp_Bobview[pos] + num) / 2
                    if pos not in Bob.cards and pos in set_ and pos is not card and Amy_hyp_Bobview[pos] is not 0 and Amy_hyp_Bobview[pos] is not 1:
                        Amy_hyp_Bobview[pos] = num
            num = 0
            for pos in Amy_hyp_Carlview:
                if pos not in Carl.cards and pos in set_ and pos is not card and Amy_hyp_Carlview[pos] is not 0 and Amy_hyp_Carlview[pos] is not 1:
                    num += 1
            if num > 0:
                num = 1 / num
                for pos in Amy_hyp_Carlview:
                    num = (Amy_hyp_Carlview[pos] + num) / 2
                    if pos not in Carl.cards and pos in set_ and pos is not card and Amy_hyp_Carlview[pos] is not 0 and Amy_hyp_Carlview[pos] is not 1:
                        Amy_hyp_Carlview[pos] = num
                        
        if who_to_ask == Bob:
            Bob_hyp_Carlview[card] = 0
            Bob_hyp_Amyview[card] = 0
        elif who_to_ask == Amy:
            Amy_hyp_Carlview[card] = 0
            Amy_hyp_Bobview[card] = 0
        elif who_to_ask == Carl:
            Carl_hyp_Amyview[card] = 0
            Carl_hyp_Bobview[card] = 0
        else:
            player_hyp_Carlview[card] = 0
            player_hyp_Bobview[card] = 0
            player_hyp_Amyview[card] = 0

        return turns[who_to_ask], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
def choose_card(bot, player, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    if bot == Carl:
        ppl_to_ask = [Bob, Amy]
        hyps = [Bob_hyp_Carlview, Amy_hyp_Carlview]
        if Bob.cards == []:
            ppl_to_ask.pop(0)
            hyps.pop(0)
        elif Amy.cards == []:
            ppl_to_ask.pop(1)
            hyps.pop(1)
    elif bot == Bob:
        ppl_to_ask = [player, Carl]
        hyps = [player_hyp_Bobview, Carl_hyp_Bobview]
        if player.cards == []:
            ppl_to_ask.pop(0)
            hyps.pop(0)
        elif Carl.cards == []:
            ppl_to_ask.pop(1)
            hyps.pop(1)
    else:
        ppl_to_ask = [player, Carl]
        hyps = [player_hyp_Amyview, Carl_hyp_Amyview]
        if player.cards == []:
            ppl_to_ask.pop(0)
            hyps.pop(0)
        elif Carl.cards == []:
            ppl_to_ask.pop(1)
            hyps.pop(1)

    if len(ppl_to_ask) == 2:
        i = np.random.randint(0,2)
        if i == 0:
            i2 = 1
        else:
            i2 = 0
        #looking for ones
        for c in hyps[i]:
            set_ = which_set(c)
            inset = False
            for card in bot.cards:
                if card in set_:
                    inset = True
            if inset == True:
                if hyps[i][c] == 1:
                    return c, ppl_to_ask[i], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
        for c in hyps[i2]:
            set_ = which_set(c)
            inset = False
            for card in bot.cards:
                if card in set_:
                    inset = True
            if inset == True:
                if hyps[i2][c] == 1:
                    return c, ppl_to_ask[i2], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
            #looking for the next greatest values

            
            
        local = hyps[i].copy()
        l = []
        for c in local:
            set_ = which_set(c)
            inset = False
            for card in bot.cards:
                if card in set_:
                    inset = True
            if inset == False:
                l.append(c)
        for thing in l:
            local.pop(thing)
        
        card1 = max(local, key=local.get)
        card1percent = local[card1]

        local = hyps[i2].copy()
        l = []
        for c in local:
            set_ = which_set(c)
            inset = False
            for card in bot.cards:
                if card in set_:
                    inset = True
            if inset == False:
                l.append(c)
        for thing in l:
            local.pop(thing)
        
        
        
        
        card2 = max(local, key=local.get)
        card2percent = local[card2]

        if card1percent > card2percent:
            return card1, ppl_to_ask[i], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
        elif card2percent > card1percent:
            return card2, ppl_to_ask[i2], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
        else:
            return card1, ppl_to_ask[i], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
    
    
    
    
    
    else:
        
        local = hyps[0].copy()
        l = []
        for c in local:
            set_ = which_set(c)
            inset = False
            for card in bot.cards:
                if card in set_:
                    inset = True
            if inset == False:
                l.append(c)
        for thing in l:
            local.pop(thing)
        
        for c in local:
            if local[c] == 1:
                return c, ppl_to_ask[0], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview
            else:
                card = max(local, key=local.get)
                return card, ppl_to_ask[0], player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
setlist = [low_d_set, low_h_set, low_c_set, low_s_set, high_d_set, high_h_set, high_c_set, high_s_set, middle_set]

# %%
def check_callstatus(bot, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    if bot == Carl:
        for set_ in setlist:
            s = set_[:]
            for c in Carl.cards:
                if c in s:
                    s.remove(c)
            for c in player_hyp_Carlview:
                if c in s and player_hyp_Carlview[c] == 1:
                    s.remove(c)
            if s == []:
                return set_
        return None
    elif bot == Bob:
        for set_ in setlist:
            s = set_[:]
            for c in Bob.cards:
                if c in s:
                    s.remove(c)
            for c in Amy_hyp_Bobview:
                if c in s and Amy_hyp_Bobview[c] == 1:
                    s.remove(c)
            if s == []:
                return set_
        return None
    else:
        for set_ in setlist:
            s = set_[:]
            for c in Amy.cards:
                if c in s:
                    s.remove(c)
            for c in Bob_hyp_Amyview:
                if c in s and Bob_hyp_Amyview[c] == 1:
                    s.remove(c)
            if s == []:
                return set_
        return None

# %%
def call_bot(set_, bot, player, Carl, Bob, Amy, teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview):
    if set_ == low_s_set:
        setname = 'low spades'
    elif set_ == low_c_set:
        setname = 'low clubs'
    elif set_ == low_h_set:
        setname = 'low hearts'
    elif set_ == low_d_set:
        setname = 'low diamonds'
    elif set_ == high_s_set:
        setname = 'high spades'
    elif set_ == high_c_set:
        setname = 'high clubs'
    elif set_ == high_h_set:
        setname = 'high hearts'
    elif set_ == high_d_set:
        setname = 'high diamonds'
    else:
        setname = 'jacks and the 8s'
    print(bot.name, " called for the ", setname)
    if bot == Carl:
        members = [player, Carl]
        teamscore += 1
        print("Success! Your team had the whole set. Your score: ", teamscore, " Opposing team score: ", oppscore)
    else:
        members = [Bob, Amy]
        oppscore += 1
        print("The opposing team had the whole set. Your score: ", teamscore, " Oppposing team score: ", oppscore)
    setlist.pop(setlist.index(set_))
    for member in members:
        for card in member.cards:
            if card in set_:
                member.cards.pop(member.cards.index(card))
    
    for s in hyplist:
        l = []
        for c in s:
            if c in set_:
                l.append(c)
        for thing in l:
            s.pop(thing)
                
    player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = deleteset(set_, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
    return teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview

# %%
def main():
    status = input("Hi there. What would you like to do?\nType r to read the rules\nType s to start a new game\nType q to quit\n")
    while status!="q":
        if status == 's':
            name = input("What is your name?")
            print("Hi", name, '\n')
            shuffle(whole_deck)
            player, Carl, Bob, Amy = setup_players(name)
            turns = {player:0, Carl:1, Bob:2, Amy:3}
            teamscore = 0
            oppscore = 0
            
            low_h_ingame = True
            low_c_ingame = True
            low_s_ingame = True
            low_d_ingame = True
            high_h_ingame = True
            high_c_ingame = True
            high_s_ingame = True
            high_d_ingame = True
            middle_ingame = True
            
            player_hyp_Carlview = {}
            for i in whole_deck:
                player_hyp_Carlview[i] = 1/54
            Carl_hyp_Bobview = {}
            for i in whole_deck:
                Carl_hyp_Bobview[i] = 1/54
          

            Bob_hyp_Carlview = Carl_hyp_Bobview.copy()
            Amy_hyp_Carlview = player_hyp_Carlview.copy()

            player_hyp_Bobview = player_hyp_Carlview.copy()
            Amy_hyp_Bobview = player_hyp_Carlview.copy()

            player_hyp_Amyview = player_hyp_Carlview.copy()
            Carl_hyp_Amyview = Carl_hyp_Bobview.copy()
            Bob_hyp_Amyview = Carl_hyp_Bobview.copy()

            
            player.cards = sort_cards(player.cards)
            check_cards(player.cards)
            initialize_hyps(player, Carl, Bob, Amy)
            print("The game will begin. Your team member is Carl.")
            gameover = False
            turn = 0
            while gameover == False:
                choice = input("Type anything to continue, type c to call, or type q to quit\n")
                if choice == 'c':  
                    teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = call(teamscore, oppscore, player, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview, low_h_ingame, low_c_ingame, low_s_ingame, low_d_ingame, high_h_ingame, high_c_ingame, high_s_ingame, high_d_ingame, middle_ingame)
                    if teamscore == 5 or oppscore == 5:
                        gameover = True
                        break
                if choice == 'q':
                    status = choice
                    break
                
                callset_Carl = check_callstatus(Carl, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                if callset_Carl is not None:
                    teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = call_bot(callset_Carl, Carl, player, Carl, Bob, Amy, teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                    if teamscore == 5 or oppscore == 5:
                        gameover = True
                        break
                callset_Bob = check_callstatus(Bob, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                if callset_Bob is not None:
                    teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = call_bot(callset_Bob, Bob, player, Carl, Bob, Amy, teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                    if teamscore == 5 or oppscore == 5:
                        gameover = True
                        break
                callset_Amy = check_callstatus(Amy, Carl, Bob, Amy, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                if callset_Amy is not None:
                    teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = call_bot(callset_Amy, Amy, player, Carl, Bob, Amy, teamscore, oppscore, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                    if teamscore == 5 or oppscore == 5:
                        gameover = True
                        break
                if player.cards == []:
                    print("You are out of cards. The game still continues.")

                """       
                print("Printing all hyps...")    
                print("player_hyp_Carlview: ", player_hyp_Carlview)   
                print("player_hyp_Bobview: ", player_hyp_Bobview)  
                print("player_hyp_Amyview: ", player_hyp_Amyview)  
                print("Carl_hyp_Bobview: ", Carl_hyp_Bobview)  
                print("Carl_hyp_Amyview: ", Carl_hyp_Amyview) 
                print("Bob_hyp_Carlview: ", Bob_hyp_Carlview)
                print("Bob_hyp_Amyview: ", Bob_hyp_Amyview)
                print("Amy_hyp_Bobview: ", Amy_hyp_Bobview) 
                print("Amy_hyp_Carlview: ", Amy_hyp_Carlview) 
                """
                    
                if turn == 0:
                    print("It is your turn.")
                    option = input("What would you like to do?\nType a to ask\nType d to check your cards\nType q to quit")
                    while option != 'a' and option != 'd' and option != 'q':
                        option = input("Please try again.")
                    status = option
                    if status == 'q':
                        break
                    while option != 'q':
                        if option == 'a':
                            who_to_ask = input("Who would you like to ask, Bob or Amy?")
                            while who_to_ask != 'Bob' and who_to_ask != 'Amy':
                                who_to_ask = input('Please try again. Make sure the first letter is capitalized.')
                            if who_to_ask == 'Bob':
                                who_to_ask = Bob
                            if who_to_ask == 'Amy':
                                who_to_ask = Amy
                            card = input("What card would you like to ask? Make sure you type in lowercase and in the format ___ of ____ or black/red joker.")
                         
                            turn, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = ask(card, who_to_ask, player, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                            break
                        if option == 'd':
                            player.cards = sort_cards(player.cards)
                            check_cards(player.cards)
                            option = input("What would you like to do?\nType a to ask\nType c to call\nType d to check your cards\nType q to quit")
                            while option != 'a' and option != 'd' and option != 'q':
                                option = input("Please try again.")
                            if option == 'q':
                                break
                elif turn == 1:
                    print("It is Carl's turn. He is your team member.")
                    turn, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = ask_bot(Carl, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                elif turn == 2:
                    print("It is Bob's turn.")
                    turn, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = ask_bot(Bob, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                else:
                    print("It is Amy's turn.")
                    turn, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview = ask_bot(Amy, player, Carl, Bob, Amy, turns, player_hyp_Carlview, player_hyp_Bobview, player_hyp_Amyview, Carl_hyp_Bobview, Carl_hyp_Amyview, Bob_hyp_Carlview, Bob_hyp_Amyview, Amy_hyp_Carlview, Amy_hyp_Bobview)
                        
            print("The game is over.")
            if teamscore == 5:
                print("Congratulations! Your team won!")
                status = 'q'
                teamscore = 0
                oppscore = 0
                break
            elif teamscore < 5:
                print("Your team lost.")
                status = 'q'
                teamscore = 0
                oppscore = 0
                break
            
           


        if status == 'r':
            print(rules)
            status = input("What would you like to do?\nType r to read the rules\nType s to start a new game\nType q to quit\n")
        else:
            status = input("Please try again. Type r, s, or q")

# %%
main()
